# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset1=pd.read_csv(r'C:\Users\rajes\Desktop\LetsUpgrade\AI-ML July20\general_data.csv')
dataset1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset1.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset1.columns[2]
# Out:
# 'BusinessTravel'

# %%
dataset1.isnull() # checking if any null value in dataset.
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset1.duplicated() # checking if any value is duplicated in data set
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset1.drop_duplicates()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset1.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
dataset1.mean()
# Out:
# Age                           36.923810
# DistanceFromHome               9.192517
# Education                      2.912925
# EmployeeCount                  1.000000
# EmployeeID                  2205.500000
# JobLevel                       2.063946
# MonthlyIncome              65029.312925
# NumCompaniesWorked             2.694830
# PercentSalaryHike             15.209524
# StandardHours                  8.000000
# StockOptionLevel               0.793878
# TotalWorkingYears             11.279936
# TrainingTimesLastYear          2.799320
# YearsAtCompany                 7.008163
# YearsSinceLastPromotion        2.187755
# YearsWithCurrManager           4.123129
# dtype: float64

# %%
dataset1.median()
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# EmployeeCount                  1.0
# EmployeeID                  2205.5
# JobLevel                       2.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# StandardHours                  8.0
# StockOptionLevel               1.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
dataset1.mode()
# Out:
#        Age Attrition BusinessTravel              Department  DistanceFromHome  \
# 0     35.0        No  Travel_Rarely  Research & Development               2.0
# 1      NaN       NaN            NaN                     NaN               NaN
# 2      NaN       NaN            NaN                     NaN               NaN
# 3      NaN       NaN            NaN                     NaN               NaN
# 4      NaN       NaN            NaN                     NaN               NaN
# ...    ...       ...            ...                     ...               ...
# 4405   NaN       NaN            NaN                     NaN               NaN
# 4406   NaN       NaN            NaN                     NaN               NaN
# 4407   NaN       NaN            NaN                     NaN               NaN
# 4408   NaN       NaN            NaN                     NaN               NaN
# 4409   NaN       NaN            NaN                     NaN               NaN
#
# ...

# %%
dataset3=dataset1.var()
dataset3
# Out:
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# EmployeeCount              0.000000e+00
# EmployeeID                 1.621042e+06
# JobLevel                   1.224760e+00
# MonthlyIncome              2.215480e+09
# NumCompaniesWorked         6.244436e+00
# PercentSalaryHike          1.338907e+01
# StandardHours              0.000000e+00
# StockOptionLevel           7.257053e-01
# TotalWorkingYears          6.056298e+01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %%
dataset4=dataset1[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].skew()

# %%
dataset4
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.026767
# PercentSalaryHike          0.820569
# TotalWorkingYears          1.116832
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
import pandas as pd
dataset1=pd.read_csv(r'C:\Users\rajes\Desktop\LetsUpgrade\AI-ML July20\general_data.csv')
dataset1.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset1.head()
dataset1
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          0  Travel_Frequently  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
#
#    Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0       0  ...                 1.0      1                11              8
# 1       0  ...                 0.0      1                23              8
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 0                 0                1.0                      6               1
# 1                 1                6.0                      3               5
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
# Print Unique values for the colums::
print('Unique values for below columns from dataset:')
print('========='*10)# just for some space lines
print(dataset0['Attrition'].unique())
print(dataset0['Over18'].unique())
print(dataset0['Gender'].unique())
print('========='*10)
# Out:
# Unique values for below columns from dataset:
# ...
# ['No' 'Yes']
# ['Y']
# ['Female' 'Male']
# ...

# %%
# Exploratory Data Analysis.
# 1. Seperate numerical and categorical variables. 
# 2. Drop any column that is not significant in decision.(like EmployeeID, Over18, Gender etc)
# 3. Label Categorical variables into numericals( like Attrition, Gender, Over18 etc)

dataset0['Attrition'] = dataset0['Attrition'].apply(lambda x:1 if x == 'Yes' else 0)
dataset0['Over18'] = dataset0['Over18'].apply(lambda x:1)

dataset0.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6b1bc8180c74> in <module>
#       4 # 3. Label Categorical variables into numericals( like Attrition, Gender, Over18 etc)
#       5
# ----> 6 dataset0['Attrition'] = dataset0['Attrition'].apply(lambda x:1 if x == 'Yes' else 0)
#       7 dataset0['Over18'] = dataset0['Over18'].apply(lambda x:1)
#       8
#
# NameError: name 'dataset0' is not defined

# %%
# Print Unique values after labelling Attritional and Over18 variables to number
print('Unique values for below columns from dataset:')
print('========='*10)# just for some space lines
print(dataset0['Attrition'].unique())
print(dataset0['Over18'].unique())

print('========='*10)
# Out:
# Unique values for below columns from dataset:
# ...
# [0 1]
# [1]
# ...

# %%
# Check Missing value or Null value in data set
import seaborn as sns
sns.heatmap(dataset0.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# We find many Null or missing values after plotting this heatmap.

ds1=dataset0.dropna(axis=1)  # droping colums having null or missing values
print(ds1)
print(ds1.isnull().sum().sum())  # printing count of null values
sns.heatmap(ds1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      51          0      Travel_Rarely                   Sales
# 1      31          1  Travel_Frequently  Research & Development
# 2      32          0  Travel_Frequently  Research & Development
# 3      38          0         Non-Travel  Research & Development
# 4      32          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 4405   42          0      Travel_Rarely  Research & Development
# 4406   29          0      Travel_Rarely  Research & Development
# 4407   25          0      Travel_Rarely  Research & Development
# 4408   42          0      Travel_Rarely                   Sales
# 4409   40          0      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %% [markdown]
# # We see now there is no missing values for any of the column

# %%
# PLot histograms to visualize the data

dataset0.hist(bins=30,figsize=(20,20),color='b')
plt.show()

# %% [markdown]
# ***By Above plot we can analyze the behaviour of data <br>
#
# 1. Max 30-40 age people are there.<br>
# 2. Attriation Rate class is highly unbalances as we can see number of people want to leave the job are more.<br>
# 3. lot of employees stay close to office.<br>
# 4. Many people got the job only by doing or after completing the Bacholers, there are very less people they have completed        there masters.<br>
# 5. Max of people are satisfied with the work enviroment. So they have less changes to leave the company.<br>
# 6. Max poeple getting average salary between 0 - 5000 dollers. and might be only those are on higher post they are getting        higher salary. <br>
# 7. Lot of people doing overtime. <br>
# 8. 0-15 percent salary hike is normal among the people. <br>
# 9. Performance rating also highly imbalances. <br>
# 10. Lot of people having the greate experience with this company and they don't want to live.We can decide it by how many years    spend at company plot

# %%
# EmployeeCount ,EmployeeID, StandardHours, Over18 there columns are not changes from one employee to another employee we can delete it
#dataset0=pd.read_csv(r'C:\Users\rajes\Desktop\LetsUpgrade\AI-ML July20\general_data.csv')
dataset0.drop(['EmployeeID','Over18','StandardHours','EmployeeCount'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-e2e6e02e6f6c> in <module>
#       1 # EmployeeCount ,EmployeeID, StandardHours, Over18 there columns are not changes from one employee to another employee we can delete it
#       2 #dataset0=pd.read_csv(r'C:\Users\rajes\Desktop\LetsUpgrade\AI-ML July20\general_data.csv')
# ----> 3 dataset0.drop(['EmployeeID','Over18','StandardHours','EmployeeCount'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
# ...

# %%
dataset0.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-67995d108097> in <module>
# ----> 1 dataset0.describe()
#
# NameError: name 'dataset0' is not defined

# %%
#Check the Attrition Rate columns.Lets print the data count,graph for it, and percentage for both the class

#fig = plt.figure(figsize=(20,2))
sns.countplot(y = ds1['Attrition'])
plt.title('Count for employee attrition')
plt.show()

# %%
# Campute percentage of Attrition::

Emp_left = ds1[ds1['Attrition'] == 1]
Emp_Stayed = ds1[ds1['Attrition'] == 0]
print(f'Percentage of People left the Company : {(len(Emp_left) / len(ds1))*100} %')
print(f'Percentage of People Stayed the Company : {(len(Emp_Stayed) / len(ds1))*100} %')
# Out:
# Percentage of People left the Company : 16.122448979591837 %
# Percentage of People Stayed the Company : 83.87755102040816 %

# %%
#Analyze the correlation Matrix for the data
from scipy.stats import pearsonr

stats,p=pearsonr(ds1.Attrition,ds1.Age) 
print(stats,p)

stats,p=pearsonr(ds1.YearsAtCompany,ds1.YearsSinceLastPromotion) 
print(stats,p)

# create heatmap plot for correlation matrix:

plt.figure(figsize=(20,20))
sns.heatmap(ds1.corr(),cmap='viridis',annot=True,fmt='.2f')
plt.show()
# Out:
# -0.15920500686577965 1.996801615886744e-26
# 0.6184088652176045 0.0

# %% [markdown]
# By Above Correlation Matrix we found below:
#
# 1.Job level is strongly correlated with total working hours
# 2.YearsSinceLastPromotion is strongly correlated with YearsAtCompany
# 3.Monthly income is strongly correlated with total working hours
# 4.Age is stongly correlated with monthly income

# %% [markdown]
# dataset0=pd.read_csv(r'C:\Users\rajes\Desktop\LetsUpgrade\AI-ML July20\general_data.csv')
# stats,_=pearsonr(dataset0.Attrition,dataset0.Age)
# print(stats,_)

# %%
plt.figure(figsize=(20,10))
sns.countplot(ds1['Age'],hue=ds1['Attrition'])
plt.show()

# %%
# Countplot to Analyze

plt.figure(figsize=(20,10))
plt.subplot(411)
sns.countplot(x=ds1['MaritalStatus'],hue=ds1['Attrition'])
plt.subplot(413)
sns.countplot(x=ds1['JobRole'],hue=ds1['Attrition'])
plt.subplot(414)
sns.countplot(x=ds1['JobLevel'],hue=ds1["Attrition"])
plt.show()

# %% [markdown]
# We Analyze below from the above countplots::
#
# 1.Most of the emp who quit are in age from 0 to 29.
# 2.Single employees tend to leave compared to married and divorced
# 3.Sales Representitives tend to leave compared to any other job
# 4.Less involved employees tend to leave the company
# 5.Less experienced (low job level) tend to leave the company

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset0.Attrition, dataset0.Age)

# %%
# Alayze Boxplot

sns.boxplot(ds1.MonthlyIncome, ds1.Gender)
sns.boxplot(ds1.Attrition, ds1.JobLevel)

# %%
sns.boxplot(ds1.MonthlyIncome, ds1.JobRole)

# %%
sns.boxplot(ds1.Attrition, ds1.MonthlyIncome)

# We find many outliers
